# %%
from preprocessing import Validator
validator = Validator()

# %%
# 800 , 0.04 : 7.475 / 17.59
# 1600, 0.03 : 7.414 / 17.58
# 2000, 0.01 : 7.615 / 17.66
# 5000, 0.01
import gc
gc.collect()
params = {
    'objective': 'l2',
    'verbosity': -1,
    'n_iter': 800,
    'lambda_l1': 0.8942112689465215,
    'lambda_l2': 6.4122663335284305,
    #'cat_l2': 7.696733748814076,
    'learning_rate': 0.04, #0.054754587005265434,
    'max_depth': 11,
    'num_leaves': 273,
    'colsample_bytree': 0.6,#0.5488343345823052,
    'colsample_bynode': 0.8,#0.7200134511260632,
    'min_data_in_leaf': 6,
    'max_cat_threshold': 952,
}
validator.build_model(params=params)
# Out:
# [100]	train's l2: 5.56277	valid's l2: 8.34543
# [200]	train's l2: 4.63931	valid's l2: 7.91159
# [300]	train's l2: 4.22147	valid's l2: 7.77297
# [400]	train's l2: 3.94735	valid's l2: 7.70836
# [500]	train's l2: 3.7373	valid's l2: 7.67245
# [600]	train's l2: 3.5717	valid's l2: 7.65205
# [700]	train's l2: 3.42764	valid's l2: 7.62663
# [800]	train's l2: 3.30958	valid's l2: 7.62241
# Weight Mean Absolute Error: 17.753872640136887

# %%
import pandas as pd
columns = validator.valid.loc[:1].drop(['sales', 'date', 'weight'], axis=1).columns.to_list()
split = validator.model.feature_importance(importance_type='split')
gain = validator.model.feature_importance(importance_type='gain')
imps = pd.DataFrame({'feature': columns, 'gain': gain, 'split': split})
imps['gain_per_split'] = (imps['gain'] / imps['split']).fillna(0)
imps = imps.sort_values('gain_per_split', ascending=False).reset_index(drop=True)
display(imps.tail(30))
# Out:
#                     feature          gain  split  gain_per_split
# 77        product_unique_id  5.790605e+05    942      614.713955
# 78          type_4_discount  1.392604e+05    228      610.791438
# 79        product_sales_364  1.179650e+06   1934      609.953330
# 80                 MCGTE_L3  7.280887e+05   1215      599.249920
# 81       weekday_frac_sales  1.280211e+06   2231      573.828362
# 82                 MCGTE_L4  5.133406e+05    915      561.028018
# 83     order_discount_ratio  6.145055e+05   1131      543.329362
# 84        relative_price_L1  1.006340e+06   1853      543.087048
# 85                warehouse  6.497721e+04    121      537.001720
# 86         product_sales_28  7.631773e+05   1441      529.616429
# 87                 MCGTE_L2  8.160710e+05   1622      503.126379
# 88                     city  1.805102e+04     36      501.417191
# 89        relative_price_L2  8.042986e+05   1617      497.401729
# 90          type_3_discount  1.568473e+04     32      490.147935
# 91        relative_price_L4  8.820358e+05   1857      474.978911
# 92        order_price_ratio  5.402423e+05   1140      473.896753
# 93         product_sales_63  8.851817e+05   1903      465.150638
# 94        day_after_closing  8.932333e+04    199      448.860934
# 95          type_5_discount  5.261691e+04    118      445.906039
# 96        product_sales_182  7.805826e+05   1788      436.567456
# 97         product_sales_35  6.083530e+05   1409      431.762266
# 98         product_sales_42  6.611529e+05   1534      430.999284
# 99                      day  1.136924e+06   2662      427.094040
# 100     relative_price_kind  7.913132e+05   1923      411.499319
# 101        product_sales_17  6.149457e+05   1570      391.685141
# 102       relative_price_L3  6.775737e+05   1756      385.862004
# 103        product_sales_91  7.071583e+05   1927      366.973690
# 104       weekday_avg_sales  5.379117e+05   1504      357.654039
# 105  winter_school_holidays  3.284667e+04    129      254.625319
# 106         school_holidays  1.126090e+04     53      212.469799
