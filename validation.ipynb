# %%
from preprocessing import Validator
validator = Validator()
params = {
    'objective': 'l2',
    'verbosity': -1,
    'n_iter': 800,
    'lambda_l1': 0.8942112689465215,
    'lambda_l2': 6.4122663335284305,
    'cat_l2': 7.696733748814076,
    'learning_rate': 0.054754587005265434,
    'max_depth': 11,
    'num_leaves': 273,
    'colsample_bytree': 0.5488343345823052,
    'colsample_bynode': 0.7200134511260632,
    'min_data_in_leaf': 6,
    'max_cat_threshold': 952,
}
validator.build_model(params=params)
# Out:
# [100]	train's l2: 273.358	valid's l2: 374.307
# [200]	train's l2: 231.349	valid's l2: 350.918
# [300]	train's l2: 207.254	valid's l2: 337.649
# [400]	train's l2: 192.183	valid's l2: 332.211
# [500]	train's l2: 180.231	valid's l2: 328.864
# [600]	train's l2: 170.699	valid's l2: 326.821
# [700]	train's l2: 162.803	valid's l2: 325.429
# [800]	train's l2: 155.912	valid's l2: 325.005
# Weight Mean Absolute Error: 20.897450411412837

# %%
import pandas as pd
columns = validator.valid.loc[:1].drop(['sales', 'date', 'weight'], axis=1).columns.to_list()
split = validator.model.feature_importance(importance_type='split')
gain = validator.model.feature_importance(importance_type='gain')
imps = pd.DataFrame({'feature': columns, 'gain': gain, 'split': split})
imps['gain_per_split'] = (imps['gain'] / imps['split']).fillna(0)
imps = imps.sort_values('gain_per_split', ascending=False).reset_index(drop=True)
display(imps)
# Out:
#                  feature          gain  split  gain_per_split
# 0              warehouse  2.762358e+09    202    1.367504e+07
# 1        sell_price_main  2.911603e+10   4480    6.499114e+06
# 2   order_discount_ratio  1.209075e+10   3592    3.366022e+06
# 3      week_moving_trend  9.589003e+09   3262    2.939609e+06
# 4     normed_week_median  9.696721e+09   3584    2.705558e+06
# ..                   ...           ...    ...             ...
# 73      product_sales_28  5.452124e+07   3036    1.795825e+04
# 74      product_sales_21  4.983896e+07   2873    1.734736e+04
# 75      product_sales_17  5.279026e+07   3236    1.631343e+04
# 76       type_1_discount  7.874907e+05     69    1.141291e+04
# 77       school_holidays  0.000000e+00      0    0.000000e+00
#
# [78 rows x 4 columns]
