# %%
from preprocessing import Validator
validator = Validator()
params = {
    'objective': 'l2',
    'verbosity': -1,
    'n_iter': 800,
    'lambda_l1': 0.8942112689465215,
    'lambda_l2': 6.4122663335284305,
    'cat_l2': 7.696733748814076,
    'learning_rate': 0.054754587005265434,
    'max_depth': 11,
    'num_leaves': 273,
    'colsample_bytree': 0.5488343345823052,
    'colsample_bynode': 0.7200134511260632,
    'min_data_in_leaf': 6,
    'max_cat_threshold': 952,
}
validator.build_model(params=params)
# Out:
# [100]	train's l2: 285.856	valid's l2: 414.898
# [200]	train's l2: 241.744	valid's l2: 387.752
# [300]	train's l2: 216.903	valid's l2: 377.685
# [400]	train's l2: 199.957	valid's l2: 372.906
# [500]	train's l2: 187.596	valid's l2: 369.381
# [600]	train's l2: 177.055	valid's l2: 366.286
# [700]	train's l2: 168.682	valid's l2: 365.185
# [800]	train's l2: 161.58	valid's l2: 364.305
# Weight Mean Absolute Error: 19.054727635451584

# %%
import pandas as pd
columns = validator.valid.loc[:1].drop(['sales', 'date', 'weight'], axis=1).columns.to_list()
split = validator.model.feature_importance(importance_type='split')
gain = validator.model.feature_importance(importance_type='gain')
imps = pd.DataFrame({'feature': columns, 'gain': gain, 'split': split})
imps['gain_per_split'] = (imps['gain'] / imps['split']).fillna(0)
imps = imps.sort_values('gain_per_split', ascending=False).reset_index(drop=True)
display(imps)
# Out:
#                  feature          gain  split  gain_per_split
# 0        sell_price_main  3.444261e+10   4298    8.013636e+06
# 1   order_discount_ratio  1.480796e+10   3886    3.810591e+06
# 2        warehouse_count  7.233701e+08    227    3.186652e+06
# 3              unique_id  8.075548e+10  25711    3.140892e+06
# 4       normed_week_mean  8.633392e+09   3182    2.713197e+06
# ..                   ...           ...    ...             ...
# 73      product_sales_21  5.599909e+07   2765    2.025284e+04
# 74    holiday_name_count  1.158155e+07    574    2.017691e+04
# 75      product_sales_28  5.935348e+07   2999    1.979109e+04
# 76       type_1_discount  1.041530e+06     72    1.446569e+04
# 77       school_holidays  0.000000e+00      0    0.000000e+00
#
# [78 rows x 4 columns]
